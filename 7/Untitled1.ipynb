# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('nba.csv')
df.head(10)
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# 5   Amir Johnson  Boston Celtics      90       PF   29   9-Jun     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 8   Terry Rozier  Boston Celtics      12       PG   22   2-Jun     190
# 9   Marcus Smart  Boston Celtics      36       PG   22   4-Jun     220
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0
# 7            Gonzaga   2165160.0
# 8         Louisville   1824360.0
# 9     Oklahoma State   3431040.0

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
# Numerical nan values
num_nan = [feat for feat in df.columns if df[feat].dtypes != 'O' and df[feat].isnull().sum() > 0]

for feat in num_nan:
    print('{} has {} % nan values'.format(feat,np.round(df[feat].isnull().mean(),4)))
# Out:
# Salary has 0.0241 % nan values

# %%
# Categorical nan values
cat_nan = [feat for feat in df.columns if df[feat].dtypes == 'O' and df[feat].isnull().sum() > 0]

for feat in cat_nan:
    print('{} has {} % nan values'.format(feat,np.round(df[feat].isnull().mean(),4)))
# Out:
# College has 0.1838 % nan values

# %%
# Handling missing values for categorical values

for feat in cat_nan:
    df[feat] = df[feat].fillna('Missing')

df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4              Missing  5000000.0
# ..                 ...        ...
# 452           Kentucky  2239800.0
# 453             Butler  2433333.0
# 454            Missing   900000.0
# 455            Missing  2900000.0
# 456             Kansas   947276.0
#
# [457 rows x 9 columns]

# %%
# Handling missing values for numerical values

for feat in num_nan:
    avg_val = np.round(df[feat].mean(),2)
    df[feat] = df[feat].fillna(avg_val)
    
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College      Salary
# 0                Texas  7730337.00
# 1            Marquette  6796117.00
# 2    Boston University  4842684.11
# 3        Georgia State  1148640.00
# 4              Missing  5000000.00
# ..                 ...         ...
# 452           Kentucky  2239800.00
# 453             Butler  2433333.00
# 454            Missing   900000.00
# 455            Missing  2900000.00
# 456             Kansas   947276.00
#
# [457 rows x 9 columns]

# %%
df['Age'] = np.where((df['Age'] >= 18) & (df['Age'] < 25),1,0)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG    0   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF    0   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG    0   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG    1   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF    0  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF    1  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG    0   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG    1   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C    0   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C    0  Jul-00     231
#
#                College      Salary
# 0                Texas  7730337.00
# 1            Marquette  6796117.00
# 2    Boston University  4842684.11
# 3        Georgia State  1148640.00
# 4              Missing  5000000.00
# ..                 ...         ...
# 452           Kentucky  2239800.00
# 453             Butler  2433333.00
# 454            Missing   900000.00
# 455            Missing  2900000.00
# 456             Kansas   947276.00
#
# [457 rows x 9 columns]

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int32
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object
